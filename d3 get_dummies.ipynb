# %%
import pandas as pd

# %%
df=pd.read_csv("Salary_Dataset.csv")
df.head()
# Out:
#   country   Salary  YearsExperience Purchased
# 0   Dubai  39343.0              1.1        No
# 1  Canada  46205.0              1.3       Yes
# 2  Canada  37731.0              1.5        No
# 3  Canada  43525.0              2.0        No
# 4     USA  39891.0              2.2        No

# %%
pd.get_dummies(df[["Purchased","country"]])
# Out:
#     Purchased_No  Purchased_Yes  country_Australia  country_Canada  \
# 0           True          False              False           False
# 1          False           True              False            True
# 2           True          False              False            True
# 3           True          False              False            True
# 4           True          False              False           False
# 5           True          False              False           False
# 6          False           True              False            True
# 7           True          False               True           False
# 8          False           True              False           False
# 9           True          False              False           False
# 10         False           True              False           False
# 11          True          False              False           False
# 12         False           True              False           False
# ...

# %%
pd.get_dummies(df[["Purchased","country"]]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Purchased_No       30 non-null     bool
#  1   Purchased_Yes      30 non-null     bool
#  2   country_Australia  30 non-null     bool
#  3   country_Canada     30 non-null     bool
#  4   country_Dubai      30 non-null     bool
#  5   country_USA        30 non-null     bool
# dtypes: bool(6)
# memory usage: 312.0 bytes
